# %%
import xgboost as xgb
from coffea.util import load
import pandas
import matplotlib.pyplot as plt
import mplhep as hep
from sklearn.model_selection import train_test_split 
import numpy as np

# %%
#result = load("/afs/cern.ch/user/a/amlevin/ewkwhjj/training_data/training_data_2016")
result = load("/afs/cern.ch/user/a/amlevin/tmp/training_data_2016")

training_data_resolved = pandas.concat(                                                                                                                                                                        
    [                                                                                                                                                                                      
        pandas.concat(                                                                                                                                                                     
            [                                                                                                                                                                              
                pandas.DataFrame(result["variables"][key].value,columns=['nextrajets','nextrabjets','leptonflavor','leptoncharge','leptonpt','leptoneta','leptonphi','met','metphi','higgs\
jet1pt','higgsjet2pt','vbfjet1pt','vbfjet2pt','higgsjet1eta','higgsjet2eta','vbfjet1eta','vbfjet2eta','higgsjet1phi','higgsjet2phi','vbfjet1phi','vbsjet2phi','higgsjet1btag','higgsjet2bt\
ag','vbfjet1btag','vbjfet2btag','higgsdijetmass','vbfdijetmass','vbfdijetabsdeta','leptonhiggsjet1mt','leptonhiggsjet2mt']),                                                               
                pandas.DataFrame(result["weights"][key].value,columns=["weight"]),                                                                                                         
                pandas.DataFrame(len(result["variables"][key].value)*[key],columns=["label"])                                                                                              
         ],axis=1)                                                                                                                                                                         
        for key in result['variables'].keys()                                                                                                                                          
    ],                                                                                                                                                                                     
ignore_index=True)

training_data_merged = pandas.concat(                                                                                                                                                                        
    [                                                                                                                                                                                      
        pandas.concat(                                                                                                                                                                     
            [                                                                                                                                                                              
                pandas.DataFrame(result["variables_merged"][key].value,columns=['higgsjetpt','higgsjeteta','higgsjetphi','higgsjetbtag1','higgsjetbtag2','higgsje\
tsoftdropmass','nextrajets','nextrabjets','leptonflavor','leptoncharge','leptonpt','leptoneta','leptonphi','met','metphi','vbfjet1pt','vbfjet2pt','vbfjet1eta','v\
bfjet2eta','vbfjet1phi','vbfjet2phi','vbfjet1btag','vbfjet2btag','vbfdijetmass','vbfdijetabsdeta','leptonvbsjet1mt','leptonvbsjet2mt']),                                                               
                pandas.DataFrame(result["weights_merged"][key].value,columns=["weight"]),                                                                                                         
                pandas.DataFrame(len(result["variables_merged"][key].value)*[key],columns=["label"])                                                                                              
         ],axis=1)                                                                                                                                                                         
        for key in result['variables_merged'].keys()                                                                                                                                          
    ],                                                                                                                                                                                     
ignore_index=True)

training_data = training_data_resolved

xs = {
    'qcdwphjj' : 0.1154*0.5840*0.33, 
    'qcdwmhjj' : 0.06917*0.5840*0.33,
    'qcdwph' : 0.2832*0.5840, 
    'qcdwmh' : 0.1770*0.5840,
    'ttsemi' : 365.4,
    'tthad' : 377.96,
    'ewkwhjj_reweighted' : 0.02656*0.5840,
    'ewkwhjj' : 0.02656*0.5840,
    'wlep' : 61526.7,
    'wlepsherpa' : 61526.7,
    'wlep2j' : 3338.0,
    'wlepfxfx0j' : 53330.0,
    'wlepfxfx1j' : 8875.0,
    'wlepfxfx2j' : 3338.0,
    'wlepmlm1j' : 8873.0,
    'wlepmlm2j' : 2793.0,
    'wlepmlm3j' : 992.5,
    'wlepmlm4j' : 380,
    'wlepht70100' : 1264.0,
    'wlepht100200' : 1256.0,
    'wlepht200400' : 335.5,
    'wlepht400600' : 45.25,
    'wlepht600800' : 10.97,
    'wlepht8001200' : 4.933,
    'wlepht12002500' : 1.16,
    'wlepht2500' : 0.008001,
    'wbb' : 215,
    'stoptchan' : 136.02,
    'santitoptchan' : 80.95
}

print(len(training_data))

print(len(training_data[training_data["label"] == "ewkwhjj"]))

print(len(training_data[training_data["label"] == "ttsemi"]))

print(len(training_data[training_data["label"].str.contains("wlepht")]))

#training_data = training_data[(training_data["label"] == "ewkwhjj") | (training_data["label"] == "ttsemi")]
training_data = training_data[(training_data["label"] == "ewkwhjj")
                              | (training_data["label"] == "ttsemi")
                              | (training_data["label"] == "stoptchan")
                              | (training_data["label"] == "santitoptchan")
                              | training_data["label"].str.contains("wlepht")
                                 ]

training_data= training_data.reset_index()

labels = []
weights = []

for i in range(len(training_data)):
    assert(training_data["label"][i] in xs.keys())
    weights.append(xs[training_data["label"][i]]/result["nevents"][training_data["label"][i]])
    if training_data["label"][i] == "ewkwhjj":
        labels.append(1)
    else:    
        labels.append(0)
        
labels=pandas.DataFrame(labels,columns=["label"])
weights=pandas.DataFrame(labels,columns=["weight"])

training_data = training_data[training_data.columns.drop(["weight","label"])]

training_data = pandas.concat([training_data,labels,weights],axis=1)
# Out:
# 116701
# 49477
# 65967
# 653

# %%
X = training_data[training_data.columns.drop(["weight","index","label"])]

w = training_data["weight"]

#print(float(len(w[w == -1]))/len(w))

y = training_data["label"]

X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(X, y, w, test_size=0.1, random_state=1)

print(len(X_train))
print(len(X_test))

dtrain = xgb.DMatrix(X_train, label=y_train)

dtest = xgb.DMatrix(X_test, label=y_test)

from xgboost import XGBRegressor

xbgr = XGBRegressor(n_estimators=400,learning_rate=0.1,verbosity=1, max_depth=6)

xbgr.fit(X_train,y_train,early_stopping_rounds=10,eval_set=[(X_test, y_test)])

xbgr.save_model("model.bin")

plt.style.use(hep.style.ROOT) 

plt.figure()

xgb.plot_importance(xbgr)

from sklearn.metrics import roc_curve, auc

y_test_pred = xbgr.predict(X_test) 

test_false_positive_rates, test_true_positive_rates, _ = roc_curve(y_test[:], y_test_pred[:])

print(auc(test_false_positive_rates, test_true_positive_rates))

y_train_pred = xbgr.predict(X_train) 

train_false_positive_rates, train_true_positive_rates, _ = roc_curve(y_train[:], y_train_pred[:])

print(auc(train_false_positive_rates, train_true_positive_rates))

plt.style.use(hep.style.ROOT) 

plt.figure()

plt.plot(1-test_false_positive_rates, test_true_positive_rates)
plt.plot(1-train_false_positive_rates, train_true_positive_rates)

plt.xlabel('Background Rejection Rate')
plt.ylabel('Signal Efficiency')
# Out:
# 104487
# 11610
# [0]	validation_0-rmse:0.48005
# [1]	validation_0-rmse:0.46312
# [2]	validation_0-rmse:0.44867
# [3]	validation_0-rmse:0.43631
# [4]	validation_0-rmse:0.42578
# [5]	validation_0-rmse:0.41688
# [6]	validation_0-rmse:0.40943
# [7]	validation_0-rmse:0.40313
# [8]	validation_0-rmse:0.39734
# [9]	validation_0-rmse:0.39283
# [10]	validation_0-rmse:0.38862
# [11]	validation_0-rmse:0.38513
# [12]	validation_0-rmse:0.38196
# [13]	validation_0-rmse:0.37925
# [14]	validation_0-rmse:0.37691
# [15]	validation_0-rmse:0.37448
# [16]	validation_0-rmse:0.37255
# [17]	validation_0-rmse:0.37054
# [18]	validation_0-rmse:0.36910
# [19]	validation_0-rmse:0.36776
# [20]	validation_0-rmse:0.36611
# [21]	validation_0-rmse:0.36483
# [22]	validation_0-rmse:0.36359
# [23]	validation_0-rmse:0.36254
# [24]	validation_0-rmse:0.36165
# [25]	validation_0-rmse:0.36082
# [26]	validation_0-rmse:0.36004
# [27]	validation_0-rmse:0.35916
# [28]	validation_0-rmse:0.35763
# [29]	validation_0-rmse:0.35700
# [30]	validation_0-rmse:0.35593
# [31]	validation_0-rmse:0.35487
# [32]	validation_0-rmse:0.35431
# [33]	validation_0-rmse:0.35370
# [34]	validation_0-rmse:0.35220
# [35]	validation_0-rmse:0.35111
# [36]	validation_0-rmse:0.35071
# [37]	validation_0-rmse:0.35023
# [38]	validation_0-rmse:0.34955
# [39]	validation_0-rmse:0.34918
# [40]	validation_0-rmse:0.34895
# [41]	validation_0-rmse:0.34835
# [42]	validation_0-rmse:0.34803
# [43]	validation_0-rmse:0.34770
# [44]	validation_0-rmse:0.34657
# [45]	validation_0-rmse:0.34624
# [46]	validation_0-rmse:0.34543
# [47]	validation_0-rmse:0.34481
# [48]	validation_0-rmse:0.34436
# [49]	validation_0-rmse:0.34415
# [50]	validation_0-rmse:0.34361
# [51]	validation_0-rmse:0.34342
# [52]	validation_0-rmse:0.34328
# [53]	validation_0-rmse:0.34313
# [54]	validation_0-rmse:0.34302
# [55]	validation_0-rmse:0.34286
# [56]	validation_0-rmse:0.34269
# [57]	validation_0-rmse:0.34230
# [58]	validation_0-rmse:0.34191
# [59]	validation_0-rmse:0.34179
# [60]	validation_0-rmse:0.34166
# [61]	validation_0-rmse:0.34157
# [62]	validation_0-rmse:0.34117
# [63]	validation_0-rmse:0.34098
# [64]	validation_0-rmse:0.34076
# [65]	validation_0-rmse:0.34072
# [66]	validation_0-rmse:0.34058
# [67]	validation_0-rmse:0.34047
# [68]	validation_0-rmse:0.33986
# [69]	validation_0-rmse:0.33946
# [70]	validation_0-rmse:0.33943
# [71]	validation_0-rmse:0.33921
# [72]	validation_0-rmse:0.33902
# [73]	validation_0-rmse:0.33893
# [74]	validation_0-rmse:0.33888
# [75]	validation_0-rmse:0.33881
# [76]	validation_0-rmse:0.33875
# [77]	validation_0-rmse:0.33866
# [78]	validation_0-rmse:0.33849
# [79]	validation_0-rmse:0.33840
# [80]	validation_0-rmse:0.33825
# [81]	validation_0-rmse:0.33802
# [82]	validation_0-rmse:0.33791
# [83]	validation_0-rmse:0.33788
# [84]	validation_0-rmse:0.33766
# [85]	validation_0-rmse:0.33763
# [86]	validation_0-rmse:0.33755
# [87]	validation_0-rmse:0.33752
# [88]	validation_0-rmse:0.33721
# [89]	validation_0-rmse:0.33700
# [90]	validation_0-rmse:0.33687
# [91]	validation_0-rmse:0.33676
# [92]	validation_0-rmse:0.33661
# [93]	validation_0-rmse:0.33658
# [94]	validation_0-rmse:0.33653
# [95]	validation_0-rmse:0.33651
# [96]	validation_0-rmse:0.33649
# [97]	validation_0-rmse:0.33644
# [98]	validation_0-rmse:0.33639
# [99]	validation_0-rmse:0.33633
# [100]	validation_0-rmse:0.33615
# [101]	validation_0-rmse:0.33609
# [102]	validation_0-rmse:0.33594
# [103]	validation_0-rmse:0.33596
# [104]	validation_0-rmse:0.33596
# [105]	validation_0-rmse:0.33597
# [106]	validation_0-rmse:0.33596
# [107]	validation_0-rmse:0.33589
# [108]	validation_0-rmse:0.33575
# [109]	validation_0-rmse:0.33554
# [110]	validation_0-rmse:0.33540
# [111]	validation_0-rmse:0.33536
# [112]	validation_0-rmse:0.33524
# [113]	validation_0-rmse:0.33515
# [114]	validation_0-rmse:0.33511
# [115]	validation_0-rmse:0.33508
# [116]	validation_0-rmse:0.33502
# [117]	validation_0-rmse:0.33502
# [118]	validation_0-rmse:0.33499
# [119]	validation_0-rmse:0.33499
# [120]	validation_0-rmse:0.33495
# [121]	validation_0-rmse:0.33493
# [122]	validation_0-rmse:0.33488
# [123]	validation_0-rmse:0.33486
# [124]	validation_0-rmse:0.33474
# [125]	validation_0-rmse:0.33471
# [126]	validation_0-rmse:0.33469
# [127]	validation_0-rmse:0.33470
# [128]	validation_0-rmse:0.33468
# [129]	validation_0-rmse:0.33469
# [130]	validation_0-rmse:0.33469
# [131]	validation_0-rmse:0.33467
# [132]	validation_0-rmse:0.33465
# [133]	validation_0-rmse:0.33463
# [134]	validation_0-rmse:0.33463
# [135]	validation_0-rmse:0.33463
# [136]	validation_0-rmse:0.33460
# [137]	validation_0-rmse:0.33461
# [138]	validation_0-rmse:0.33459
# [139]	validation_0-rmse:0.33451
# [140]	validation_0-rmse:0.33450
# [141]	validation_0-rmse:0.33437
# [142]	validation_0-rmse:0.33427
# [143]	validation_0-rmse:0.33417
# [144]	validation_0-rmse:0.33412
# [145]	validation_0-rmse:0.33409
# [146]	validation_0-rmse:0.33406
# [147]	validation_0-rmse:0.33407
# [148]	validation_0-rmse:0.33406
# [149]	validation_0-rmse:0.33403
# [150]	validation_0-rmse:0.33401
# [151]	validation_0-rmse:0.33395
# [152]	validation_0-rmse:0.33374
# [153]	validation_0-rmse:0.33374
# [154]	validation_0-rmse:0.33374
# [155]	validation_0-rmse:0.33373
# [156]	validation_0-rmse:0.33360
# [157]	validation_0-rmse:0.33346
# [158]	validation_0-rmse:0.33340
# [159]	validation_0-rmse:0.33339
# [160]	validation_0-rmse:0.33336
# [161]	validation_0-rmse:0.33331
# [162]	validation_0-rmse:0.33330
# [163]	validation_0-rmse:0.33329
# [164]	validation_0-rmse:0.33330
# [165]	validation_0-rmse:0.33329
# [166]	validation_0-rmse:0.33328
# [167]	validation_0-rmse:0.33329
# [168]	validation_0-rmse:0.33329
# [169]	validation_0-rmse:0.33328
# [170]	validation_0-rmse:0.33326
# [171]	validation_0-rmse:0.33325
# [172]	validation_0-rmse:0.33322
# [173]	validation_0-rmse:0.33321
# [174]	validation_0-rmse:0.33316
# [175]	validation_0-rmse:0.33316
# [176]	validation_0-rmse:0.33316
# [177]	validation_0-rmse:0.33315
# [178]	validation_0-rmse:0.33308
# [179]	validation_0-rmse:0.33298
# [180]	validation_0-rmse:0.33294
# [181]	validation_0-rmse:0.33294
# [182]	validation_0-rmse:0.33293
# [183]	validation_0-rmse:0.33293
# [184]	validation_0-rmse:0.33295
# [185]	validation_0-rmse:0.33296
# [186]	validation_0-rmse:0.33297
# [187]	validation_0-rmse:0.33295
# [188]	validation_0-rmse:0.33295
# [189]	validation_0-rmse:0.33294
# [190]	validation_0-rmse:0.33292
# [191]	validation_0-rmse:0.33292
# [192]	validation_0-rmse:0.33292
# [193]	validation_0-rmse:0.33291
# [194]	validation_0-rmse:0.33291
# [195]	validation_0-rmse:0.33290
# [196]	validation_0-rmse:0.33294
# [197]	validation_0-rmse:0.33293
# [198]	validation_0-rmse:0.33293
# [199]	validation_0-rmse:0.33294
# [200]	validation_0-rmse:0.33296
# [201]	validation_0-rmse:0.33296
# [202]	validation_0-rmse:0.33294
# [203]	validation_0-rmse:0.33290
# [204]	validation_0-rmse:0.33291
# [205]	validation_0-rmse:0.33291
# 0.9231773480645474
# 0.9469886226008956
# Text(0, 1, 'Signal Efficiency')
