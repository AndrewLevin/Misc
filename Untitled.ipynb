# %%
import xgboost as xgb
from coffea.util import load
import pandas
import matplotlib.pyplot as plt
import mplhep as hep
from sklearn.model_selection import train_test_split 
import numpy as np

# %%
result = load("/afs/cern.ch/user/a/amlevin/ewkwhjj/training_data/training_data_2016")

training_data_resolved = pandas.concat(                                                                                                                                                                        
    [                                                                                                                                                                                      
        pandas.concat(                                                                                                                                                                     
            [                                                                                                                                                                              
                pandas.DataFrame(result["variables"][key].value,columns=['nextrajets','nextrabjets','leptonflavor','leptoncharge','leptonpt','leptoneta','leptonphi','met','metphi','higgs\
jet1pt','higgsjet2pt','vbfjet1pt','vbfjet2pt','higgsjet1eta','higgsjet2eta','vbfjet1eta','vbfjet2eta','higgsjet1phi','higgsjet2phi','vbfjet1phi','vbsjet2phi','higgsjet1btag','higgsjet2bt\
ag','vbfjet1btag','vbjfet2btag','higgsdijetmass','vbfdijetmass','vbfdijetabsdeta','leptonhiggsjet1mt','leptonhiggsjet2mt']),                                                               
                pandas.DataFrame(result["weights"][key].value,columns=["weight"]),                                                                                                         
                pandas.DataFrame(len(result["variables"][key].value)*[key],columns=["label"])                                                                                              
         ],axis=1)                                                                                                                                                                         
        for key in result['variables'].keys()                                                                                                                                          
    ],                                                                                                                                                                                     
ignore_index=True)

training_data_merged = pandas.concat(                                                                                                                                                                        
    [                                                                                                                                                                                      
        pandas.concat(                                                                                                                                                                     
            [                                                                                                                                                                              
                pandas.DataFrame(result["variables_merged"][key].value,columns=['higgsjetpt','higgsjeteta','higgsjetphi','higgsjetbtag1','higgsjetbtag2','higgsje\
tsoftdropmass','nextrajets','nextrabjets','leptonflavor','leptoncharge','leptonpt','leptoneta','leptonphi','met','metphi','vbfjet1pt','vbfjet2pt','vbfjet1eta','v\
bfjet2eta','vbfjet1phi','vbfjet2phi','vbfjet1btag','vbfjet2btag','vbfdijetmass','vbfdijetabsdeta','leptonvbsjet1mt','leptonvbsjet2mt']),                                                               
                pandas.DataFrame(result["weights_merged"][key].value,columns=["weight"]),                                                                                                         
                pandas.DataFrame(len(result["variables_merged"][key].value)*[key],columns=["label"])                                                                                              
         ],axis=1)                                                                                                                                                                         
        for key in result['variables_merged'].keys()                                                                                                                                          
    ],                                                                                                                                                                                     
ignore_index=True)

training_data = training_data_resolved

# %%
xs = {
    'qcdwphjj' : 0.1154*0.5840*0.33, 
    'qcdwmhjj' : 0.06917*0.5840*0.33,
    'qcdwph' : 0.2832*0.5840, 
    'qcdwmh' : 0.1770*0.5840,
    'ttsemi' : 365.4,
    'tthad' : 377.96,
    'ewkwhjj_reweighted' : 0.02656*0.5840,
    'ewkwhjj' : 0.02656*0.5840,
    'wlep' : 61526.7,
    'wlep2j' : 3338.0,
    'wbb' : 215,
    'stoptchan' : 136.02,
    'santitoptchan' : 80.95
}

print(len(training_data[training_data["label"] == "ewkwhjj"]))

print(len(training_data[training_data["label"] == "ttsemi"]))

#training_data = training_data[(training_data["label"] == "ewkwhjj") | (training_data["label"] == "ttsemi")]
training_data = training_data[(training_data["label"] == "ewkwhjj")
                              | (training_data["label"] == "ttsemi")
                              | (training_data["label"] == "stoptchan")
                              | (training_data["label"] == "santitoptchan")
                                 ]

training_data= training_data.reset_index()

labels = []
weights = []

for i in range(len(training_data)):
    assert(training_data["label"][i] in xs.keys())
    weights.append(xs[training_data["label"][i]]/result["nevents"][training_data["label"][i]])
    if training_data["label"][i] == "ewkwhjj":
        labels.append(1)
    else:    
        labels.append(0)
        
labels=pandas.DataFrame(labels,columns=["label"])
weights=pandas.DataFrame(labels,columns=["weight"])

training_data = training_data[training_data.columns.drop(["weight","label"])]

training_data = pandas.concat([training_data,labels,weights],axis=1)
# Out:
# 37709
# 52541

# %%
X = training_data[training_data.columns.drop(["weight","index","label"])]

w = training_data["weight"]

#print(float(len(w[w == -1]))/len(w))

y = training_data["label"]

X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(X, y, w, test_size=0.1, random_state=1)

print(len(X_train))
print(len(X_test))

dtrain = xgb.DMatrix(X_train, label=y_train)

dtest = xgb.DMatrix(X_test, label=y_test)

from xgboost import XGBRegressor

xbgr = XGBRegressor(n_estimators=400,learning_rate=0.1,verbosity=1, max_depth=6)

xbgr.fit(X_train,y_train,early_stopping_rounds=10,eval_set=[(X_test, y_test)])

xbgr.save_model("model.bin")

plt.style.use(hep.style.ROOT) 

plt.figure()

xgb.plot_importance(xbgr)

from sklearn.metrics import roc_curve, auc

y_test_pred = xbgr.predict(X_test) 

test_false_positive_rates, test_true_positive_rates, _ = roc_curve(y_test[:], y_test_pred[:])

print(auc(test_false_positive_rates, test_true_positive_rates))

y_train_pred = xbgr.predict(X_train) 

train_false_positive_rates, train_true_positive_rates, _ = roc_curve(y_train[:], y_train_pred[:])

print(auc(train_false_positive_rates, train_true_positive_rates))

plt.style.use(hep.style.ROOT) 

plt.figure()

plt.plot(1-test_false_positive_rates, test_true_positive_rates)
plt.plot(1-train_false_positive_rates, train_true_positive_rates)

plt.xlabel('Background Rejection Rate')
plt.ylabel('Signal Efficiency')
# Out:
# 86609
# 9624
# [0]	validation_0-rmse:0.48109
# [1]	validation_0-rmse:0.46512
# [2]	validation_0-rmse:0.45153
# [3]	validation_0-rmse:0.43999
# [4]	validation_0-rmse:0.43015
# [5]	validation_0-rmse:0.42180
# [6]	validation_0-rmse:0.41479
# [7]	validation_0-rmse:0.40877
# [8]	validation_0-rmse:0.40363
# [9]	validation_0-rmse:0.39939
# [10]	validation_0-rmse:0.39559
# [11]	validation_0-rmse:0.39245
# [12]	validation_0-rmse:0.38960
# [13]	validation_0-rmse:0.38702
# [14]	validation_0-rmse:0.38486
# [15]	validation_0-rmse:0.38288
# [16]	validation_0-rmse:0.38072
# [17]	validation_0-rmse:0.37908
# [18]	validation_0-rmse:0.37790
# [19]	validation_0-rmse:0.37639
# [20]	validation_0-rmse:0.37510
# [21]	validation_0-rmse:0.37353
# [22]	validation_0-rmse:0.37258
# [23]	validation_0-rmse:0.37141
# [24]	validation_0-rmse:0.37049
# [25]	validation_0-rmse:0.36969
# [26]	validation_0-rmse:0.36895
# [27]	validation_0-rmse:0.36828
# [28]	validation_0-rmse:0.36670
# [29]	validation_0-rmse:0.36611
# [30]	validation_0-rmse:0.36524
# [31]	validation_0-rmse:0.36360
# [32]	validation_0-rmse:0.36323
# [33]	validation_0-rmse:0.36266
# [34]	validation_0-rmse:0.36131
# [35]	validation_0-rmse:0.36094
# [36]	validation_0-rmse:0.36051
# [37]	validation_0-rmse:0.35914
# [38]	validation_0-rmse:0.35821
# [39]	validation_0-rmse:0.35804
# [40]	validation_0-rmse:0.35789
# [41]	validation_0-rmse:0.35710
# [42]	validation_0-rmse:0.35684
# [43]	validation_0-rmse:0.35602
# [44]	validation_0-rmse:0.35519
# [45]	validation_0-rmse:0.35490
# [46]	validation_0-rmse:0.35470
# [47]	validation_0-rmse:0.35457
# [48]	validation_0-rmse:0.35396
# [49]	validation_0-rmse:0.35379
# [50]	validation_0-rmse:0.35356
# [51]	validation_0-rmse:0.35321
# [52]	validation_0-rmse:0.35296
# [53]	validation_0-rmse:0.35286
# [54]	validation_0-rmse:0.35266
# [55]	validation_0-rmse:0.35251
# [56]	validation_0-rmse:0.35215
# [57]	validation_0-rmse:0.35168
# [58]	validation_0-rmse:0.35157
# [59]	validation_0-rmse:0.35137
# [60]	validation_0-rmse:0.35111
# [61]	validation_0-rmse:0.35100
# [62]	validation_0-rmse:0.35091
# [63]	validation_0-rmse:0.35070
# [64]	validation_0-rmse:0.35065
# [65]	validation_0-rmse:0.35053
# [66]	validation_0-rmse:0.35037
# [67]	validation_0-rmse:0.35011
# [68]	validation_0-rmse:0.34998
# [69]	validation_0-rmse:0.34992
# [70]	validation_0-rmse:0.34973
# [71]	validation_0-rmse:0.34966
# [72]	validation_0-rmse:0.34964
# [73]	validation_0-rmse:0.34964
# [74]	validation_0-rmse:0.34940
# [75]	validation_0-rmse:0.34910
# [76]	validation_0-rmse:0.34903
# [77]	validation_0-rmse:0.34889
# [78]	validation_0-rmse:0.34851
# [79]	validation_0-rmse:0.34839
# [80]	validation_0-rmse:0.34822
# [81]	validation_0-rmse:0.34818
# [82]	validation_0-rmse:0.34817
# [83]	validation_0-rmse:0.34808
# [84]	validation_0-rmse:0.34793
# [85]	validation_0-rmse:0.34790
# [86]	validation_0-rmse:0.34765
# [87]	validation_0-rmse:0.34748
# [88]	validation_0-rmse:0.34725
# [89]	validation_0-rmse:0.34719
# [90]	validation_0-rmse:0.34714
# [91]	validation_0-rmse:0.34715
# [92]	validation_0-rmse:0.34709
# [93]	validation_0-rmse:0.34700
# [94]	validation_0-rmse:0.34691
# [95]	validation_0-rmse:0.34664
# [96]	validation_0-rmse:0.34663
# [97]	validation_0-rmse:0.34651
# [98]	validation_0-rmse:0.34648
# [99]	validation_0-rmse:0.34639
# [100]	validation_0-rmse:0.34635
# [101]	validation_0-rmse:0.34638
# [102]	validation_0-rmse:0.34633
# [103]	validation_0-rmse:0.34631
# [104]	validation_0-rmse:0.34620
# [105]	validation_0-rmse:0.34614
# [106]	validation_0-rmse:0.34604
# [107]	validation_0-rmse:0.34606
# [108]	validation_0-rmse:0.34605
# [109]	validation_0-rmse:0.34603
# [110]	validation_0-rmse:0.34603
# [111]	validation_0-rmse:0.34603
# [112]	validation_0-rmse:0.34599
# [113]	validation_0-rmse:0.34596
# [114]	validation_0-rmse:0.34598
# [115]	validation_0-rmse:0.34601
# [116]	validation_0-rmse:0.34598
# [117]	validation_0-rmse:0.34596
# [118]	validation_0-rmse:0.34595
# [119]	validation_0-rmse:0.34586
# [120]	validation_0-rmse:0.34582
# [121]	validation_0-rmse:0.34575
# [122]	validation_0-rmse:0.34575
# [123]	validation_0-rmse:0.34576
# [124]	validation_0-rmse:0.34575
# [125]	validation_0-rmse:0.34577
# [126]	validation_0-rmse:0.34574
# [127]	validation_0-rmse:0.34573
# [128]	validation_0-rmse:0.34577
# [129]	validation_0-rmse:0.34577
# [130]	validation_0-rmse:0.34580
# [131]	validation_0-rmse:0.34578
# [132]	validation_0-rmse:0.34575
# [133]	validation_0-rmse:0.34576
# [134]	validation_0-rmse:0.34578
# [135]	validation_0-rmse:0.34576
# [136]	validation_0-rmse:0.34576
# [137]	validation_0-rmse:0.34571
# [138]	validation_0-rmse:0.34568
# [139]	validation_0-rmse:0.34567
# [140]	validation_0-rmse:0.34546
# [141]	validation_0-rmse:0.34543
# [142]	validation_0-rmse:0.34544
# [143]	validation_0-rmse:0.34545
# [144]	validation_0-rmse:0.34532
# [145]	validation_0-rmse:0.34531
# [146]	validation_0-rmse:0.34528
# [147]	validation_0-rmse:0.34520
# [148]	validation_0-rmse:0.34523
# [149]	validation_0-rmse:0.34525
# [150]	validation_0-rmse:0.34524
# [151]	validation_0-rmse:0.34524
# [152]	validation_0-rmse:0.34523
# [153]	validation_0-rmse:0.34523
# [154]	validation_0-rmse:0.34524
# [155]	validation_0-rmse:0.34519
# [156]	validation_0-rmse:0.34518
# [157]	validation_0-rmse:0.34514
# [158]	validation_0-rmse:0.34514
# [159]	validation_0-rmse:0.34507
# [160]	validation_0-rmse:0.34492
# [161]	validation_0-rmse:0.34483
# [162]	validation_0-rmse:0.34482
# [163]	validation_0-rmse:0.34478
# [164]	validation_0-rmse:0.34476
# [165]	validation_0-rmse:0.34475
# [166]	validation_0-rmse:0.34472
# [167]	validation_0-rmse:0.34472
# [168]	validation_0-rmse:0.34473
# [169]	validation_0-rmse:0.34471
# [170]	validation_0-rmse:0.34471
# [171]	validation_0-rmse:0.34471
# [172]	validation_0-rmse:0.34464
# [173]	validation_0-rmse:0.34465
# [174]	validation_0-rmse:0.34464
# [175]	validation_0-rmse:0.34464
# [176]	validation_0-rmse:0.34462
# [177]	validation_0-rmse:0.34464
# [178]	validation_0-rmse:0.34468
# [179]	validation_0-rmse:0.34462
# [180]	validation_0-rmse:0.34468
# [181]	validation_0-rmse:0.34467
# [182]	validation_0-rmse:0.34467
# [183]	validation_0-rmse:0.34467
# [184]	validation_0-rmse:0.34465
# [185]	validation_0-rmse:0.34451
# [186]	validation_0-rmse:0.34452
# [187]	validation_0-rmse:0.34452
# [188]	validation_0-rmse:0.34453
# [189]	validation_0-rmse:0.34449
# [190]	validation_0-rmse:0.34449
# [191]	validation_0-rmse:0.34448
# [192]	validation_0-rmse:0.34449
# [193]	validation_0-rmse:0.34440
# [194]	validation_0-rmse:0.34441
# [195]	validation_0-rmse:0.34441
# [196]	validation_0-rmse:0.34436
# [197]	validation_0-rmse:0.34432
# [198]	validation_0-rmse:0.34431
# [199]	validation_0-rmse:0.34424
# [200]	validation_0-rmse:0.34427
# [201]	validation_0-rmse:0.34425
# [202]	validation_0-rmse:0.34425
# [203]	validation_0-rmse:0.34423
# [204]	validation_0-rmse:0.34420
# [205]	validation_0-rmse:0.34421
# [206]	validation_0-rmse:0.34420
# [207]	validation_0-rmse:0.34419
# [208]	validation_0-rmse:0.34424
# [209]	validation_0-rmse:0.34425
# [210]	validation_0-rmse:0.34426
# [211]	validation_0-rmse:0.34425
# [212]	validation_0-rmse:0.34426
# [213]	validation_0-rmse:0.34415
# [214]	validation_0-rmse:0.34417
# [215]	validation_0-rmse:0.34415
# [216]	validation_0-rmse:0.34412
# [217]	validation_0-rmse:0.34412
# [218]	validation_0-rmse:0.34414
# [219]	validation_0-rmse:0.34410
# [220]	validation_0-rmse:0.34411
# [221]	validation_0-rmse:0.34412
# [222]	validation_0-rmse:0.34412
# [223]	validation_0-rmse:0.34413
# [224]	validation_0-rmse:0.34409
# [225]	validation_0-rmse:0.34407
# [226]	validation_0-rmse:0.34400
# [227]	validation_0-rmse:0.34398
# [228]	validation_0-rmse:0.34402
# [229]	validation_0-rmse:0.34400
# [230]	validation_0-rmse:0.34400
# [231]	validation_0-rmse:0.34390
# [232]	validation_0-rmse:0.34391
# [233]	validation_0-rmse:0.34390
# [234]	validation_0-rmse:0.34388
# [235]	validation_0-rmse:0.34388
# [236]	validation_0-rmse:0.34388
# [237]	validation_0-rmse:0.34389
# [238]	validation_0-rmse:0.34385
# [239]	validation_0-rmse:0.34375
# [240]	validation_0-rmse:0.34368
# [241]	validation_0-rmse:0.34362
# [242]	validation_0-rmse:0.34362
# [243]	validation_0-rmse:0.34362
# [244]	validation_0-rmse:0.34364
# [245]	validation_0-rmse:0.34361
# [246]	validation_0-rmse:0.34362
# [247]	validation_0-rmse:0.34362
# [248]	validation_0-rmse:0.34361
# [249]	validation_0-rmse:0.34362
# [250]	validation_0-rmse:0.34362
# [251]	validation_0-rmse:0.34359
# [252]	validation_0-rmse:0.34355
# [253]	validation_0-rmse:0.34352
# [254]	validation_0-rmse:0.34353
# [255]	validation_0-rmse:0.34354
# [256]	validation_0-rmse:0.34355
# [257]	validation_0-rmse:0.34355
# [258]	validation_0-rmse:0.34357
# [259]	validation_0-rmse:0.34359
# [260]	validation_0-rmse:0.34358
# [261]	validation_0-rmse:0.34358
# [262]	validation_0-rmse:0.34357
# [263]	validation_0-rmse:0.34351
# [264]	validation_0-rmse:0.34350
# [265]	validation_0-rmse:0.34347
# [266]	validation_0-rmse:0.34347
# [267]	validation_0-rmse:0.34338
# [268]	validation_0-rmse:0.34339
# [269]	validation_0-rmse:0.34338
# [270]	validation_0-rmse:0.34336
# [271]	validation_0-rmse:0.34336
# [272]	validation_0-rmse:0.34336
# [273]	validation_0-rmse:0.34337
# [274]	validation_0-rmse:0.34339
# [275]	validation_0-rmse:0.34341
# [276]	validation_0-rmse:0.34340
# [277]	validation_0-rmse:0.34339
# [278]	validation_0-rmse:0.34342
# [279]	validation_0-rmse:0.34343
# [280]	validation_0-rmse:0.34343
# [281]	validation_0-rmse:0.34343
# 0.9102463371778055
# 0.9506641113285537
# Text(0, 1, 'Signal Efficiency')
