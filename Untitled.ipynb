# %%
import xgboost as xgb
from coffea.util import load
import pandas
import matplotlib.pyplot as plt
import mplhep as hep
from sklearn.model_selection import train_test_split 
import numpy as np

# %%
result = load("/afs/cern.ch/user/a/amlevin/ewkwhjj/training_data/training_data_2016")

training_data_resolved = pandas.concat(                                                                                                                                                                        
    [                                                                                                                                                                                      
        pandas.concat(                                                                                                                                                                     
            [                                                                                                                                                                              
                pandas.DataFrame(result["variables"][key].value,columns=['nextrajets','nextrabjets','leptonflavor','leptoncharge','leptonpt','leptoneta','leptonphi','met','metphi','higgs\
jet1pt','higgsjet2pt','vbfjet1pt','vbfjet2pt','higgsjet1eta','higgsjet2eta','vbfjet1eta','vbfjet2eta','higgsjet1phi','higgsjet2phi','vbfjet1phi','vbsjet2phi','higgsjet1btag','higgsjet2bt\
ag','vbfjet1btag','vbjfet2btag','higgsdijetmass','vbfdijetmass','vbfdijetabsdeta','leptonhiggsjet1mt','leptonhiggsjet2mt']),                                                               
                pandas.DataFrame(result["weights"][key].value,columns=["weight"]),                                                                                                         
                pandas.DataFrame(len(result["variables"][key].value)*[key],columns=["label"])                                                                                              
         ],axis=1)                                                                                                                                                                         
        for key in result['variables'].keys()                                                                                                                                          
    ],                                                                                                                                                                                     
ignore_index=True)

training_data_merged = pandas.concat(                                                                                                                                                                        
    [                                                                                                                                                                                      
        pandas.concat(                                                                                                                                                                     
            [                                                                                                                                                                              
                pandas.DataFrame(result["variables_merged"][key].value,columns=['higgsjetpt','higgsjeteta','higgsjetphi','higgsjetbtag1','higgsjetbtag2','higgsje\
tsoftdropmass','nextrajets','nextrabjets','leptonflavor','leptoncharge','leptonpt','leptoneta','leptonphi','met','metphi','vbfjet1pt','vbfjet2pt','vbfjet1eta','v\
bfjet2eta','vbfjet1phi','vbfjet2phi','vbfjet1btag','vbfjet2btag','vbfdijetmass','vbfdijetabsdeta','leptonvbsjet1mt','leptonvbsjet2mt']),                                                               
                pandas.DataFrame(result["weights_merged"][key].value,columns=["weight"]),                                                                                                         
                pandas.DataFrame(len(result["variables_merged"][key].value)*[key],columns=["label"])                                                                                              
         ],axis=1)                                                                                                                                                                         
        for key in result['variables_merged'].keys()                                                                                                                                          
    ],                                                                                                                                                                                     
ignore_index=True)

training_data = training_data_merged

# %%
xs = {
    'qcdwphjj' : 0.1154*0.5840*0.33, 
    'qcdwmhjj' : 0.06917*0.5840*0.33,
    'qcdwph' : 0.2832*0.5840, 
    'qcdwmh' : 0.1770*0.5840,
    'ttsemi' : 365.4,
    'tthad' : 377.96,
    'ewkwhjj_reweighted' : 0.02656*0.5840,
    'ewkwhjj' : 0.02656*0.5840,
    'wlep' : 61526.7,
    'wlep2j' : 3338.0,
    'wbb' : 215,
    'stoptchan' : 136.02,
    'santitoptchan' : 80.95
}

print(len(training_data[training_data["label"] == "ewkwhjj"]))

print(len(training_data[training_data["label"] == "ttsemi"]))

#training_data = training_data[(training_data["label"] == "ewkwhjj") | (training_data["label"] == "ttsemi")]
training_data = training_data[(training_data["label"] == "ewkwhjj")
                              | (training_data["label"] == "ttsemi")
                              | (training_data["label"] == "stoptchan")
                              | (training_data["label"] == "santitoptchan")
                                 ]

training_data= training_data.reset_index()

labels = []
weights = []

for i in range(len(training_data)):
    assert(training_data["label"][i] in xs.keys())
    weights.append(xs[training_data["label"][i]]/result["nevents"][training_data["label"][i]])
    if training_data["label"][i] == "ewkwhjj":
        labels.append(1)
    else:    
        labels.append(0)
        
labels=pandas.DataFrame(labels,columns=["label"])
weights=pandas.DataFrame(labels,columns=["weight"])

training_data = training_data[training_data.columns.drop(["weight","label"])]

training_data = pandas.concat([training_data,labels,weights],axis=1)
# Out:
# 51113
# 213001

# %%
X = training_data[training_data.columns.drop(["weight","index","label"])]

w = training_data["weight"]

#print(float(len(w[w == -1]))/len(w))

y = training_data["label"]

X_train, X_test, y_train, y_test, w_train, w_test = train_test_split(X, y, w, test_size=0.1, random_state=1)

print(len(X_train))
print(len(X_test))

dtrain = xgb.DMatrix(X_train, label=y_train)

dtest = xgb.DMatrix(X_test, label=y_test)

from xgboost import XGBRegressor

xbgr = XGBRegressor(n_estimators=400,learning_rate=0.1,verbosity=1, max_depth=6)

#xbgr =  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#             importance_type='gain', interaction_constraints='',
#             learning_rate=0.1, max_delta_step=0, max_depth=2,
#             min_child_weight=1, monotone_constraints='()',
#             n_estimators=400, n_jobs=64, num_parallel_tree=1, random_state=0,
#             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#             tree_method='exact', validate_parameters=1, verbosity=2)

xbgr.fit(X_train,y_train,early_stopping_rounds=10,eval_set=[(X_test, y_test)])

xbgr.save_model("model.bin")

plt.style.use(hep.style.ROOT) 

plt.figure()

xgb.plot_importance(xbgr)

from sklearn.metrics import roc_curve, auc

y_test_pred = xbgr.predict(X_test) 

test_false_positive_rates, test_true_positive_rates, _ = roc_curve(y_test[:], y_test_pred[:])

print(auc(test_false_positive_rates, test_true_positive_rates))

y_train_pred = xbgr.predict(X_train) 

train_false_positive_rates, train_true_positive_rates, _ = roc_curve(y_train[:], y_train_pred[:])

print(auc(train_false_positive_rates, train_true_positive_rates))

plt.style.use(hep.style.ROOT) 

plt.figure()

plt.plot(1-test_false_positive_rates, test_true_positive_rates)
plt.plot(1-train_false_positive_rates, train_true_positive_rates)

plt.xlabel('Background Rejection Rate')
plt.ylabel('Signal Efficiency')
# Out:
# 246669
# 27408
# [0]	validation_0-rmse:0.47216
# [1]	validation_0-rmse:0.44830
# [2]	validation_0-rmse:0.42784
# [3]	validation_0-rmse:0.41034
# [4]	validation_0-rmse:0.39538
# [5]	validation_0-rmse:0.38287
# [6]	validation_0-rmse:0.37218
# [7]	validation_0-rmse:0.36317
# [8]	validation_0-rmse:0.35569
# [9]	validation_0-rmse:0.34928
# [10]	validation_0-rmse:0.34395
# [11]	validation_0-rmse:0.33942
# [12]	validation_0-rmse:0.33574
# [13]	validation_0-rmse:0.33259
# [14]	validation_0-rmse:0.32990
# [15]	validation_0-rmse:0.32769
# [16]	validation_0-rmse:0.32577
# [17]	validation_0-rmse:0.32420
# [18]	validation_0-rmse:0.32280
# [19]	validation_0-rmse:0.32149
# [20]	validation_0-rmse:0.32028
# [21]	validation_0-rmse:0.31917
# [22]	validation_0-rmse:0.31840
# [23]	validation_0-rmse:0.31767
# [24]	validation_0-rmse:0.31701
# [25]	validation_0-rmse:0.31647
# [26]	validation_0-rmse:0.31583
# [27]	validation_0-rmse:0.31527
# [28]	validation_0-rmse:0.31473
# [29]	validation_0-rmse:0.31433
# [30]	validation_0-rmse:0.31391
# [31]	validation_0-rmse:0.31350
# [32]	validation_0-rmse:0.31294
# [33]	validation_0-rmse:0.31264
# [34]	validation_0-rmse:0.31239
# [35]	validation_0-rmse:0.31194
# [36]	validation_0-rmse:0.31168
# [37]	validation_0-rmse:0.31144
# [38]	validation_0-rmse:0.31108
# [39]	validation_0-rmse:0.31083
# [40]	validation_0-rmse:0.31006
# [41]	validation_0-rmse:0.30983
# [42]	validation_0-rmse:0.30971
# [43]	validation_0-rmse:0.30928
# [44]	validation_0-rmse:0.30910
# [45]	validation_0-rmse:0.30886
# [46]	validation_0-rmse:0.30880
# [47]	validation_0-rmse:0.30834
# [48]	validation_0-rmse:0.30814
# [49]	validation_0-rmse:0.30781
# [50]	validation_0-rmse:0.30769
# [51]	validation_0-rmse:0.30762
# [52]	validation_0-rmse:0.30740
# [53]	validation_0-rmse:0.30726
# [54]	validation_0-rmse:0.30703
# [55]	validation_0-rmse:0.30681
# [56]	validation_0-rmse:0.30673
# [57]	validation_0-rmse:0.30647
# [58]	validation_0-rmse:0.30630
# [59]	validation_0-rmse:0.30620
# [60]	validation_0-rmse:0.30605
# [61]	validation_0-rmse:0.30599
# [62]	validation_0-rmse:0.30581
# [63]	validation_0-rmse:0.30560
# [64]	validation_0-rmse:0.30552
# [65]	validation_0-rmse:0.30543
# [66]	validation_0-rmse:0.30536
# [67]	validation_0-rmse:0.30525
# [68]	validation_0-rmse:0.30519
# [69]	validation_0-rmse:0.30517
# [70]	validation_0-rmse:0.30501
# [71]	validation_0-rmse:0.30498
# [72]	validation_0-rmse:0.30487
# [73]	validation_0-rmse:0.30464
# [74]	validation_0-rmse:0.30451
# [75]	validation_0-rmse:0.30444
# [76]	validation_0-rmse:0.30443
# [77]	validation_0-rmse:0.30429
# [78]	validation_0-rmse:0.30419
# [79]	validation_0-rmse:0.30407
# [80]	validation_0-rmse:0.30407
# [81]	validation_0-rmse:0.30395
# [82]	validation_0-rmse:0.30392
# [83]	validation_0-rmse:0.30387
# [84]	validation_0-rmse:0.30385
# [85]	validation_0-rmse:0.30359
# [86]	validation_0-rmse:0.30357
# [87]	validation_0-rmse:0.30356
# [88]	validation_0-rmse:0.30339
# [89]	validation_0-rmse:0.30332
# [90]	validation_0-rmse:0.30328
# [91]	validation_0-rmse:0.30320
# [92]	validation_0-rmse:0.30313
# [93]	validation_0-rmse:0.30305
# [94]	validation_0-rmse:0.30302
# [95]	validation_0-rmse:0.30288
# [96]	validation_0-rmse:0.30280
# [97]	validation_0-rmse:0.30277
# [98]	validation_0-rmse:0.30276
# [99]	validation_0-rmse:0.30271
# [100]	validation_0-rmse:0.30267
# [101]	validation_0-rmse:0.30266
# [102]	validation_0-rmse:0.30260
# [103]	validation_0-rmse:0.30251
# [104]	validation_0-rmse:0.30250
# [105]	validation_0-rmse:0.30250
# [106]	validation_0-rmse:0.30248
# [107]	validation_0-rmse:0.30246
# [108]	validation_0-rmse:0.30244
# [109]	validation_0-rmse:0.30241
# [110]	validation_0-rmse:0.30227
# [111]	validation_0-rmse:0.30216
# [112]	validation_0-rmse:0.30215
# [113]	validation_0-rmse:0.30206
# [114]	validation_0-rmse:0.30201
# [115]	validation_0-rmse:0.30198
# [116]	validation_0-rmse:0.30197
# [117]	validation_0-rmse:0.30192
# [118]	validation_0-rmse:0.30178
# [119]	validation_0-rmse:0.30173
# [120]	validation_0-rmse:0.30171
# [121]	validation_0-rmse:0.30163
# [122]	validation_0-rmse:0.30162
# [123]	validation_0-rmse:0.30158
# [124]	validation_0-rmse:0.30154
# [125]	validation_0-rmse:0.30147
# [126]	validation_0-rmse:0.30141
# [127]	validation_0-rmse:0.30139
# [128]	validation_0-rmse:0.30138
# [129]	validation_0-rmse:0.30136
# [130]	validation_0-rmse:0.30125
# [131]	validation_0-rmse:0.30122
# [132]	validation_0-rmse:0.30114
# [133]	validation_0-rmse:0.30111
# [134]	validation_0-rmse:0.30092
# [135]	validation_0-rmse:0.30091
# [136]	validation_0-rmse:0.30085
# [137]	validation_0-rmse:0.30086
# [138]	validation_0-rmse:0.30083
# [139]	validation_0-rmse:0.30082
# [140]	validation_0-rmse:0.30079
# [141]	validation_0-rmse:0.30078
# [142]	validation_0-rmse:0.30065
# [143]	validation_0-rmse:0.30064
# [144]	validation_0-rmse:0.30063
# [145]	validation_0-rmse:0.30060
# [146]	validation_0-rmse:0.30058
# [147]	validation_0-rmse:0.30029
# [148]	validation_0-rmse:0.30025
# [149]	validation_0-rmse:0.30019
# [150]	validation_0-rmse:0.30010
# [151]	validation_0-rmse:0.30008
# [152]	validation_0-rmse:0.30006
# [153]	validation_0-rmse:0.30001
# [154]	validation_0-rmse:0.29995
# [155]	validation_0-rmse:0.29993
# [156]	validation_0-rmse:0.29991
# [157]	validation_0-rmse:0.29988
# [158]	validation_0-rmse:0.29979
# [159]	validation_0-rmse:0.29975
# [160]	validation_0-rmse:0.29967
# [161]	validation_0-rmse:0.29963
# [162]	validation_0-rmse:0.29957
# [163]	validation_0-rmse:0.29956
# [164]	validation_0-rmse:0.29957
# [165]	validation_0-rmse:0.29957
# [166]	validation_0-rmse:0.29953
# [167]	validation_0-rmse:0.29952
# [168]	validation_0-rmse:0.29919
# [169]	validation_0-rmse:0.29917
# [170]	validation_0-rmse:0.29880
# [171]	validation_0-rmse:0.29877
# [172]	validation_0-rmse:0.29874
# [173]	validation_0-rmse:0.29865
# [174]	validation_0-rmse:0.29865
# [175]	validation_0-rmse:0.29861
# [176]	validation_0-rmse:0.29856
# [177]	validation_0-rmse:0.29849
# [178]	validation_0-rmse:0.29848
# [179]	validation_0-rmse:0.29846
# [180]	validation_0-rmse:0.29845
# [181]	validation_0-rmse:0.29841
# [182]	validation_0-rmse:0.29830
# [183]	validation_0-rmse:0.29828
# [184]	validation_0-rmse:0.29824
# [185]	validation_0-rmse:0.29806
# [186]	validation_0-rmse:0.29798
# [187]	validation_0-rmse:0.29795
# [188]	validation_0-rmse:0.29787
# [189]	validation_0-rmse:0.29781
# [190]	validation_0-rmse:0.29780
# [191]	validation_0-rmse:0.29779
# [192]	validation_0-rmse:0.29751
# [193]	validation_0-rmse:0.29748
# [194]	validation_0-rmse:0.29747
# [195]	validation_0-rmse:0.29745
# [196]	validation_0-rmse:0.29722
# [197]	validation_0-rmse:0.29722
# [198]	validation_0-rmse:0.29718
# [199]	validation_0-rmse:0.29718
# [200]	validation_0-rmse:0.29717
# [201]	validation_0-rmse:0.29712
# [202]	validation_0-rmse:0.29712
# [203]	validation_0-rmse:0.29702
# [204]	validation_0-rmse:0.29701
# [205]	validation_0-rmse:0.29701
# [206]	validation_0-rmse:0.29700
# [207]	validation_0-rmse:0.29699
# [208]	validation_0-rmse:0.29681
# [209]	validation_0-rmse:0.29682
# [210]	validation_0-rmse:0.29680
# [211]	validation_0-rmse:0.29677
# [212]	validation_0-rmse:0.29678
# [213]	validation_0-rmse:0.29677
# [214]	validation_0-rmse:0.29676
# [215]	validation_0-rmse:0.29676
# [216]	validation_0-rmse:0.29653
# [217]	validation_0-rmse:0.29652
# [218]	validation_0-rmse:0.29650
# [219]	validation_0-rmse:0.29650
# [220]	validation_0-rmse:0.29647
# [221]	validation_0-rmse:0.29646
# [222]	validation_0-rmse:0.29646
# [223]	validation_0-rmse:0.29644
# [224]	validation_0-rmse:0.29634
# [225]	validation_0-rmse:0.29633
# [226]	validation_0-rmse:0.29632
# [227]	validation_0-rmse:0.29633
# [228]	validation_0-rmse:0.29630
# [229]	validation_0-rmse:0.29630
# [230]	validation_0-rmse:0.29620
# [231]	validation_0-rmse:0.29620
# [232]	validation_0-rmse:0.29619
# [233]	validation_0-rmse:0.29619
# [234]	validation_0-rmse:0.29619
# [235]	validation_0-rmse:0.29618
# [236]	validation_0-rmse:0.29618
# [237]	validation_0-rmse:0.29618
# [238]	validation_0-rmse:0.29615
# [239]	validation_0-rmse:0.29605
# [240]	validation_0-rmse:0.29601
# [241]	validation_0-rmse:0.29601
# [242]	validation_0-rmse:0.29602
# [243]	validation_0-rmse:0.29604
# [244]	validation_0-rmse:0.29604
# [245]	validation_0-rmse:0.29603
# [246]	validation_0-rmse:0.29601
# [247]	validation_0-rmse:0.29601
# [248]	validation_0-rmse:0.29599
# [249]	validation_0-rmse:0.29600
# [250]	validation_0-rmse:0.29597
# [251]	validation_0-rmse:0.29598
# [252]	validation_0-rmse:0.29598
# [253]	validation_0-rmse:0.29598
# [254]	validation_0-rmse:0.29582
# [255]	validation_0-rmse:0.29581
# [256]	validation_0-rmse:0.29579
# [257]	validation_0-rmse:0.29579
# [258]	validation_0-rmse:0.29579
# [259]	validation_0-rmse:0.29575
# [260]	validation_0-rmse:0.29574
# [261]	validation_0-rmse:0.29574
# [262]	validation_0-rmse:0.29574
# [263]	validation_0-rmse:0.29574
# [264]	validation_0-rmse:0.29573
# [265]	validation_0-rmse:0.29573
# [266]	validation_0-rmse:0.29573
# [267]	validation_0-rmse:0.29573
# [268]	validation_0-rmse:0.29566
# [269]	validation_0-rmse:0.29563
# [270]	validation_0-rmse:0.29562
# [271]	validation_0-rmse:0.29561
# [272]	validation_0-rmse:0.29561
# [273]	validation_0-rmse:0.29559
# [274]	validation_0-rmse:0.29558
# [275]	validation_0-rmse:0.29557
# [276]	validation_0-rmse:0.29557
# [277]	validation_0-rmse:0.29556
# [278]	validation_0-rmse:0.29549
# [279]	validation_0-rmse:0.29546
# [280]	validation_0-rmse:0.29546
# [281]	validation_0-rmse:0.29545
# [282]	validation_0-rmse:0.29545
# [283]	validation_0-rmse:0.29545
# [284]	validation_0-rmse:0.29545
# [285]	validation_0-rmse:0.29545
# [286]	validation_0-rmse:0.29538
# [287]	validation_0-rmse:0.29537
# [288]	validation_0-rmse:0.29535
# [289]	validation_0-rmse:0.29533
# [290]	validation_0-rmse:0.29535
# [291]	validation_0-rmse:0.29534
# [292]	validation_0-rmse:0.29534
# [293]	validation_0-rmse:0.29521
# [294]	validation_0-rmse:0.29519
# [295]	validation_0-rmse:0.29519
# [296]	validation_0-rmse:0.29519
# [297]	validation_0-rmse:0.29520
# [298]	validation_0-rmse:0.29514
# [299]	validation_0-rmse:0.29512
# [300]	validation_0-rmse:0.29511
# [301]	validation_0-rmse:0.29511
# [302]	validation_0-rmse:0.29511
# [303]	validation_0-rmse:0.29511
# [304]	validation_0-rmse:0.29510
# [305]	validation_0-rmse:0.29511
# [306]	validation_0-rmse:0.29510
# [307]	validation_0-rmse:0.29511
# [308]	validation_0-rmse:0.29510
# [309]	validation_0-rmse:0.29510
# [310]	validation_0-rmse:0.29508
# [311]	validation_0-rmse:0.29509
# [312]	validation_0-rmse:0.29509
# [313]	validation_0-rmse:0.29498
# [314]	validation_0-rmse:0.29498
# [315]	validation_0-rmse:0.29498
# [316]	validation_0-rmse:0.29498
# [317]	validation_0-rmse:0.29496
# [318]	validation_0-rmse:0.29485
# [319]	validation_0-rmse:0.29484
# [320]	validation_0-rmse:0.29484
# [321]	validation_0-rmse:0.29485
# [322]	validation_0-rmse:0.29483
# [323]	validation_0-rmse:0.29484
# [324]	validation_0-rmse:0.29482
# [325]	validation_0-rmse:0.29484
# [326]	validation_0-rmse:0.29480
# [327]	validation_0-rmse:0.29480
# [328]	validation_0-rmse:0.29480
# [329]	validation_0-rmse:0.29480
# [330]	validation_0-rmse:0.29481
# [331]	validation_0-rmse:0.29480
# [332]	validation_0-rmse:0.29479
# [333]	validation_0-rmse:0.29480
# [334]	validation_0-rmse:0.29480
# [335]	validation_0-rmse:0.29480
# [336]	validation_0-rmse:0.29480
# [337]	validation_0-rmse:0.29479
# [338]	validation_0-rmse:0.29478
# [339]	validation_0-rmse:0.29475
# [340]	validation_0-rmse:0.29474
# [341]	validation_0-rmse:0.29474
# [342]	validation_0-rmse:0.29474
# [343]	validation_0-rmse:0.29475
# [344]	validation_0-rmse:0.29474
# [345]	validation_0-rmse:0.29474
# [346]	validation_0-rmse:0.29473
# [347]	validation_0-rmse:0.29466
# [348]	validation_0-rmse:0.29459
# [349]	validation_0-rmse:0.29458
# [350]	validation_0-rmse:0.29461
# [351]	validation_0-rmse:0.29460
# [352]	validation_0-rmse:0.29459
# [353]	validation_0-rmse:0.29459
# [354]	validation_0-rmse:0.29447
# [355]	validation_0-rmse:0.29446
# [356]	validation_0-rmse:0.29444
# [357]	validation_0-rmse:0.29446
# [358]	validation_0-rmse:0.29445
# [359]	validation_0-rmse:0.29444
# [360]	validation_0-rmse:0.29445
# [361]	validation_0-rmse:0.29445
# [362]	validation_0-rmse:0.29447
# [363]	validation_0-rmse:0.29448
