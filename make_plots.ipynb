# %%
from coffea.util import load
from coffea import hist
import matplotlib.pyplot as plt
import mplhep as hep

f = load("outfile_2016")

lumi=35.9
#lumi=138

for k in f.keys():
    if not hasattr(f[k],"scale"):
        continue  

#    f[k].scale({"TTBarSemi" : lumi*1000*365.4/f["sumw"]["TTBarSemi"],'W':lumi*1000*61526.7/f["sumw"]["W"],'TTBarHad':lumi*1000*377.96/f["sumw"]["TTBarHad"],"WW" : lumi*1000*64.3/f["sumw"]["WW"],'Signal':lumi*1000*0.0184/f["sumw"]["Signal"]},axis="dataset")
        
#    f[k].scale({"TTBarSemi" : lumi*1000*365.4/f["sumw"]["TTBarSemi"],'Signal':lumi*1000*0.0184/f["sumw"]["Signal"]},axis="dataset")
    f[k].scale({"qcdwhjj" : lumi*1000*0.08968/f["sumw"]["qcdwhjj"],'w':lumi*1000*61526.7/f["sumw"]["w"],"ww" : lumi*1000*64.3/f["sumw"]["ww"],'tthad':lumi*1000*377.96/f["sumw"]["tthad"],"ttsemi" : lumi*1000*365.4/f["sumw"]["ttsemi"],'ewkwhjj':lumi*1000*0.0184/f["sumw"]["ewkwhjj"]},axis="dataset")

#remove_list = ["ww","w","tthad"]
remove_list = []
    
data_err_opts = {
    'linestyle': 'none',
    'marker': '.',
    'markersize': 10.,
    'color': 'k',
    'elinewidth': 1,
}    
    
plt.style.use(hep.style.CMS)                                                                                                                                          

bdtscorefig1, ax = plt.subplots()

hist.plot1d(f["sel3_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over",density=True)

ax.set_xlabel('BDT score')
#ax.set_ylabel('Events per bin')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

bdtscorefig2, ax = plt.subplots()

hist.plot1d(f["sel3_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"),density=True)

ax.set_xlabel('BDT score')
#ax.set_ylabel('Events per bin')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

bdtscorefig3, ax = plt.subplots()

hist.plot1d(f["sel3_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over")

ax.set_xlabel('BDT score')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

bdtscorefig4, ax = plt.subplots()

hist.plot1d(f["sel3_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"))

ax.set_xlabel('BDT score')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

bdtscorefig5, ax = plt.subplots()

hist.plot1d(f["sel3_bdtscore_binning2"].remove(["Data"]+remove_list,"dataset"))

ax.set_xlabel('BDT score')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

bdtscorefig6, ax = plt.subplots()

hist.plot1d(f["sel3_bdtscore_binning2"].remove(["Data"]+remove_list,"dataset"),density=True)

ax.set_xlabel('BDT score')
ax.set_ylim(0.0001, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

higgsdijetmassfig1, ax = plt.subplots()

hist.plot1d(f["sel3_higgsdijetmass_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1)

ax.set_xlabel('Higgs dijet mass [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

higgsdijetmassfig2, ax = plt.subplots()

hist.plot1d(f["sel3_higgsdijetmass_binning1"].remove(["Data","TTBarSemi"]+remove_list,"dataset"),stack=1)

ax.set_xlabel('Higgs dijet mass [GeV]')
ax.set_ylabel('Events per bin')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

higgsdijetmassfig3, ax = plt.subplots()

hist.plot1d(f["sel6_higgsdijetmass_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1)
hist.plot1d(f["sel6_higgsdijetmass_binning1"]["Data"],overflow="over",error_opts=data_err_opts)

ax.set_xlabel('Higs dijet mass [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, 1000000)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

vbsdijetmassfig1, ax = plt.subplots()

hist.plot1d(f["sel3_vbsdijetmass_binning2"].remove(["Data"]+remove_list,"dataset"),stack=1,overflow="over")

ax.set_xlabel('VBS dijet mass [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

vbsdijetmassfig2, ax = plt.subplots()

hist.plot1d(f["sel6_vbsdijetmass_binning2"].remove(["Data"]+remove_list,"dataset"),stack=1)
hist.plot1d(f["sel6_vbsdijetmass_binning2"]["Data"],overflow="over",error_opts=data_err_opts)

ax.set_xlabel('VBS dijet mass [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.1,10000000000)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

vbsdijetdetajjfig1, ax = plt.subplots()

hist.plot1d(f["sel3_vbsdijetabsdeta_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1,overflow="over")

ax.set_xlabel('VBS dijet $\Delta \eta$')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

vbsdijetdetajjfig2, ax = plt.subplots()

hist.plot1d(f["sel3_vbsdijetabsdeta_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over",density=True)

ax.set_xlabel('VBS dijet $\Delta \eta$')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

leptonptfig1, ax = plt.subplots()

hist.plot1d(f["sel3_leptonpt_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1,overflow="over")

ax.set_xlabel('Lepton $p_T$ [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

leptonptfig2, ax = plt.subplots()

hist.plot1d(f["sel3_leptonpt_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over",density=True)

ax.set_xlabel('Lepton $p_T$ [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.0001, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

leptonptfig3, ax = plt.subplots()

hist.plot1d(f["sel6_leptonpt_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1)
hist.plot1d(f["sel6_leptonpt_binning1"]["Data"],overflow="over",error_opts=data_err_opts)

ax.set_xlabel('Lepton $p_T$ [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.1,10000000)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

metfig1, ax = plt.subplots()

hist.plot1d(f["sel3_met_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1,overflow="over")

ax.set_xlabel('MET [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

metfig2, ax = plt.subplots()

hist.plot1d(f["sel3_met_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over",density=True)

ax.set_xlabel('MET [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.0005, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

metfig3, ax = plt.subplots()

hist.plot1d(f["sel6_met_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1)
hist.plot1d(f["sel6_met_binning1"]["Data"],overflow="over",error_opts=data_err_opts)

ax.set_xlabel('MET [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.1,100000000)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

higgsjetsoftdropmassfig1, ax = plt.subplots()

hist.plot1d(f["sel9_higgsjetsoftdropmass_binning1"].remove(["Data"]+remove_list,"dataset"),stack=1)

ax.set_xlabel('Higgs jet soft drop mass [GeV]')
ax.set_ylabel('Events per bin')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

sel9bdtscorefig1, ax = plt.subplots()

hist.plot1d(f["sel9_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over",density=True)

ax.set_xlabel('BDT score')
#ax.set_ylabel('Events per bin')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

sel9bdtscorefig2, ax = plt.subplots()

hist.plot1d(f["sel9_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"),density=True)

ax.set_xlabel('BDT score')
#ax.set_ylabel('Events per bin')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

sel9bdtscorefig3, ax = plt.subplots()

hist.plot1d(f["sel9_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"),overflow="over")

ax.set_xlabel('BDT score')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

sel9bdtscorefig4, ax = plt.subplots()

hist.plot1d(f["sel9_bdtscore_binning1"].remove(["Data"]+remove_list,"dataset"))

ax.set_xlabel('BDT score')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

sel9bdtscorefig5, ax = plt.subplots()

hist.plot1d(f["sel9_bdtscore_binning2"].remove(["Data"]+remove_list,"dataset"))

ax.set_xlabel('BDT score')
ax.set_ylim(0.01, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")

sel9bdtscorefig6, ax = plt.subplots()

hist.plot1d(f["sel9_bdtscore_binning2"].remove(["Data"]+remove_list,"dataset"),density=True)

ax.set_xlabel('BDT score')
ax.set_ylim(0.0001, None)
ax.set_yscale('log')
                                                                                                                                                                         
hep.cms.lumitext("{} fb$^{{-1}}$".format(lumi))
hep.cms.text("Preliminary")
# Out:
# /afs/cern.ch/user/a/amlevin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:267: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# (exptext: Custom Text(0.001, 1, 'CMS'),
#  expsuffix: Custom Text(0.001, 1.005, 'Preliminary'))
